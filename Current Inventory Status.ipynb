# %% [markdown]
# # SEE CURRENT INVENTORY STATUS (AFTER PURCHASES)

# %%
import json
import pandas as pd

fd = open("store_record.json",'r')
txt = fd.read()
fd.close()
rec = json.loads(txt)

df = pd.DataFrame(rec)
df
# Out:
#                 1001          1002         1003            1004  \
# item            Rice    Masoor_Dal  Wheat flour           Spice
# price             50           110           40             100
# company   India Gate  Tata sampann   Ganesh Ata  Everest Spices
# stock           9983         10000        10000             600
# exp_date  31/12/2023    31/12/2023   31/12/2022      31/12/2022
# discount          10             5            5              10
#
#                        1005        1006        1007        1008        1009  \
# item                  Sugar        Salt         Tea       Coffe     Biscuit
# price                    40          35         700        1000          30
# company   M.G Food Products        Tata   Tata Gold    Nescaffe    Biskfarm
# stock                  9990       10000        5000        4998         490
# exp_date         31/12/2023  31/12/2023  31/12/2022  31/12/2022  31/12/2022
# ...

# %% [markdown]
# # View current Sales record status

# %%
import json
import pandas as pd

fd = open("sales_record.json",'r')
txt = fd.read()
fd.close()
rec = json.loads(txt)

df = pd.DataFrame(rec)
df
# Out:
#                                                                  1  \
# Name                                                        Pratap
# Mobile No.                                                    7854
# Purchase_record  {'Items': ['Wheat flour'], 'Company': ['Ganesh...
# Total cost                                                   190.0
# Payble amount                                                190.0
# Time                                      Fri Sep  3 00:22:37 2021
#
#                                                                  2  \
# Name                                                        Bikram
# Mobile No.                                                     785
# Purchase_record  {'Items': ['Wheat flour'], 'Company': ['Ganesh...
# Total cost                                                   190.0
# Payble amount                                                190.0
# Time                                      Fri Sep  3 00:26:35 2021
#
# ...

# %% [markdown]
# # Search Sales report by purchaser's Name:

# %%
import json

fd = open("sales_record.json",'r')
txt = fd.read()
fd.close()
rec = json.loads(txt)

name = str(input("Enter name :"))

for i in rec:
    if(rec[i]['Name']==name):
        print("Bill no :",i)
        print(rec[i])
# Out:
# Enter name :Jogendra Pandit
# Bill no : 8
# {'Name': 'Jogendra Pandit', 'Mobile No.': '7854123694', 'Purchase_record': {'Items': ['Sugar', 'Butter', 'Munch'], 'Company': ['M.G Food Products', 'Amul', 'Nestle'], 'Price/item': [40, 25, 25], 'Quantity': [5, 1, 3], 'Discount %': [10, 0, 10], 'Amount': [180.0, 25.0, 67.5]}, 'Total cost': 272.5, 'Payble amount': 272.5, 'Time': 'Sat Sep  4 13:20:03 2021'}
