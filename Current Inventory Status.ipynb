# %% [markdown]
# # SEE CURRENT INVENTORY STATUS (AFTER PURCHASES)

# %%
import json
import pandas as pd

fd = open("store_record.json",'r')
txt = fd.read()
fd.close()
rec = json.loads(txt)

df = pd.DataFrame(rec)
df
# Out:
#                 1001          1002         1003            1004  \
# item            Rice    Masoor_Dal  Wheat flour           Spice
# price             50           110           40             100
# company   India Gate  Tata sampann   Ganesh Ata  Everest Spices
# stock           9990          9990         9990             600
# exp_date  31/12/2023    31/12/2023   31/12/2022      31/12/2022
# discount          10             5            5              10
#
#                        1005        1006        1007        1008        1009  \
# item                  Sugar        Salt         Tea       Coffe     Biscuit
# price                    40          35         700        1000          30
# company   M.G Food Products        Tata   Tata Gold    Nescaffe    Biskfarm
# stock                 10000       10000        5000        5000         450
# exp_date         31/12/2023  31/12/2023  31/12/2022  31/12/2022  31/12/2022
# discount                 10           5          10           5          10
#
#                         1010  ...        1022        1023        1024  \
# item                   Bread  ...      5 star       Lay's    Thums up
# price                     24  ...          20          25          65
# company     Modern Food Ltd.  ...   Cadbury's       Lay's    CocaCola
# stock                    100  ...         250         246         248
# exp_date  Best before 7 days  ...  31/12/2022  31/12/2022  31/12/2022
# discount                   5  ...          10          10          10
#
#                         1025        1026            1027       1028  1029  \
# item      Fruit juice(mango)        Soap  Washing powder       Copy   Pen
# price                     75          75             100         60    10
# company     Dabur India Ltd.       Nivea       Serf Exel  Classmate  Link
# stock                    246         598             600        600   600
# exp_date          31/12/2022  31/12/2022      31/12/2022
# discount                  10          10              10         10    10
#
#                 1030        1031
# item          Pencil   Sanitizer
# price              5         160
# company       Apsara    Lifebuoy
# stock            500         150
# exp_date  31/12/2022  31/12/2021
# discount          10          10
#
# [6 rows x 31 columns]

# %% [markdown]
# # View current Sales record status

# %%
import json
import pandas as pd

fd = open("sales_record.json",'r')
txt = fd.read()
fd.close()
rec = json.loads(txt)

df = pd.DataFrame(rec)
df
# Out:
#                                                                  1  \
# Name                                                        Pratap
# Mobile No.                                                    7854
# Purchase_record  {'Items': ['Wheat flour'], 'Company': ['Ganesh...
# Total cost                                                   190.0
# Payble amount                                                190.0
# Time                                      Fri Sep  3 00:22:37 2021
#
#                                                                  2  \
# Name                                                        Bikram
# Mobile No.                                                     785
# Purchase_record  {'Items': ['Wheat flour'], 'Company': ['Ganesh...
# Total cost                                                   190.0
# Payble amount                                                190.0
# Time                                      Fri Sep  3 00:26:35 2021
#
#                                                                  3
# Name                                                        Pratik
# Mobile No.                                                   78964
# Purchase_record  {'Items': ['Masoor_Dal'], 'Company': ['Tata sa...
# Total cost                                                   522.5
# Payble amount                                                522.5
# Time                                      Fri Sep  3 00:27:38 2021
